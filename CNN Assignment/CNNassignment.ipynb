# %% [markdown]
# # **CNN assignment**(Do read the note at the end)

# %% [markdown]
# Description: Here we are going to use CNN to classify images of elephants,tigers,cheetah's and crocodiles. Basically multiclass classificiation using CNN.

# %% [markdown]
# **Q.1** Import all required modules

# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Dropout, MaxPooling2D, Flatten, GlobalAveragePooling2D
import numpy as np
import matplotlib.pyplot as plt
import zipfile

# %% [markdown]
# **Q.2** Load data using image_dataset_from_directory(https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory)

# %%
with zipfile.ZipFile('data.zip', 'r') as zip_ref:
    zip_ref.extractall('data')
data = image_dataset_from_directory(
    'data',
    image_size = (128, 128),
    labels = 'inferred',
    label_mode = 'int',
    crop_to_aspect_ratio = True,
    shuffle = True,
)
# Out:
# Found 1658 files belonging to 4 classes.

# %% [markdown]
# *   Since data object is not iterable,we will create a nummpy iterator for data.
# *   Then use batch to iterate through our data

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %% [markdown]
# Run the below code and batch code 2-3 times to visualise the labels given to different animals.

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# **Q.3** Map the data such that all pixel values lie between 0 and 1 using the **lambda function**

# %%
data = data.map(lambda x, y: (tf.keras.layers.Rescaling(1./255)(x), y))

# %% [markdown]
# **Q.4** Split the data into train set and test set(and validation set if needed) using **data.take**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-class-take-method/) and **data.skip**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-skip-method/)

# %%
train_dataset = data.take(50).cache().prefetch(buffer_size = tf.data.AUTOTUNE)
test_dataset = data.skip(50).cache().prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# **Creating the model**

# %% [markdown]
# **Q.5** Write code to create CNN model including fully connected layers with softmax as final layer.

# %%
strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    model = Sequential([
        Input((128, 128, 3)),
        Conv2D(32, (3, 3), activation = 'relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation = 'relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation = 'relu'),
        MaxPooling2D(2, 2),
        Conv2D(256, (3, 3), activation = 'relu'),
        Dropout(0.5),
        MaxPooling2D(2, 2),
        Conv2D(512, (3, 3), activation = 'relu'),
        GlobalAveragePooling2D(),
        Flatten(),
        Dense(1024, activation = 'relu'),
        Dense(4, activation = 'softmax'),
    ])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %% [markdown]
# **Q.6** Compile your model

# %%
model.compile(
    loss = tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.0001),
    metrics = ['accuracy'],
)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %% [markdown]
# **Q.7** Fit your model with train set and make sure to keep **less epochs**(10-15) as the dataset size is very large.

# %%
model.fit(
    train_dataset,
    epochs = 40,
    batch_size = 32,
)
# Out:
# Epoch 1/40
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 50/50 [==============================] - 10s 62ms/step - loss: 1.3484 - accuracy: 0.3250
# Epoch 2/40
# 50/50 [==============================] - 3s 51ms/step - loss: 1.2641 - accuracy: 0.4050
# Epoch 3/40
# 50/50 [==============================] - 3s 51ms/step - loss: 1.1962 - accuracy: 0.4719
# Epoch 4/40
# 50/50 [==============================] - 3s 50ms/step - loss: 1.1325 - accuracy: 0.5181
# Epoch 5/40
# 50/50 [==============================] - 3s 51ms/step - loss: 1.0742 - accuracy: 0.5531
# Epoch 6/40
# 50/50 [==============================] - 3s 51ms/step - loss: 1.0218 - accuracy: 0.5825
# Epoch 7/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.9773 - accuracy: 0.5956
# Epoch 8/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.9410 - accuracy: 0.6200
# Epoch 9/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.9083 - accuracy: 0.6338
# Epoch 10/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.8795 - accuracy: 0.6531
# Epoch 11/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.8465 - accuracy: 0.6656
# Epoch 12/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.8233 - accuracy: 0.6762
# Epoch 13/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.8013 - accuracy: 0.6913
# Epoch 14/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.7709 - accuracy: 0.7006
# Epoch 15/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.7531 - accuracy: 0.6981
# Epoch 16/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.7447 - accuracy: 0.7150
# Epoch 17/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.7108 - accuracy: 0.7262
# Epoch 18/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.7036 - accuracy: 0.7406
# Epoch 19/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.6729 - accuracy: 0.7481
# Epoch 20/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.6625 - accuracy: 0.7531
# Epoch 21/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.6457 - accuracy: 0.7581
# Epoch 22/40
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6304 - accuracy: 0.7675
# Epoch 23/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.6113 - accuracy: 0.7706
# Epoch 24/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.5994 - accuracy: 0.7756
# Epoch 25/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.5812 - accuracy: 0.7775
# Epoch 26/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.5656 - accuracy: 0.7844
# Epoch 27/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.5520 - accuracy: 0.7887
# Epoch 28/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.5402 - accuracy: 0.7981
# Epoch 29/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.5305 - accuracy: 0.8069
# Epoch 30/40
# 50/50 [==============================] - 2s 50ms/step - loss: 0.5153 - accuracy: 0.8181
# Epoch 31/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.5030 - accuracy: 0.8181
# Epoch 32/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4949 - accuracy: 0.8194
# Epoch 33/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4781 - accuracy: 0.8288
# Epoch 34/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4679 - accuracy: 0.8288
# Epoch 35/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4676 - accuracy: 0.8313
# Epoch 36/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.4518 - accuracy: 0.8431
# Epoch 37/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4301 - accuracy: 0.8431
# Epoch 38/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4390 - accuracy: 0.8413
# Epoch 39/40
# 50/50 [==============================] - 3s 51ms/step - loss: 0.4187 - accuracy: 0.8481
# Epoch 40/40
# 50/50 [==============================] - 3s 50ms/step - loss: 0.4065 - accuracy: 0.8550

# %% [markdown]
# **Q.8** Test your code with test set

# %%
loss,accuracy = model.evaluate(test_dataset)
# Out:
# 2/2 [==============================] - 6s 369ms/step - loss: 0.3901 - accuracy: 0.8621

# %%
# Do not change this code
if accuracy>=0.85:
  print(f"Congratulations, CNN assignment complete!! Your accuracy is {accuracy}")
else:
  print(f"Try again, not enough accuracy! Your accuracy is {accuracy}" )
# Out:
# Congratulations, CNN assignment complete!! Your accuracy is 0.8620689511299133

# %% [markdown]
# **Note: 1. Many of you will get very high train accuracy but low test accuracy. This is called overfitting, this can be solved by increasing the train set size. If your getting low accuracy for both train and test, modify your layers in the model.**
#
# **2.Do use T4GPU.Ideally your first epoch will take quite sometime and rest of the epochs will be faster but if all your epochs are taking a lot of time, try starting a new gpu session(open a new gmail account and open colab on that) because your free gpu might have exhausted itself.**
#
# **3.Other than that everything should be fine, happy learning!!**
